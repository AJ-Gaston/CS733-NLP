# %%
import pandas
#Read in original dataset
unfiltered_reviews_pd = pandas.read_csv('./dataset_Google-Maps-Reviews-Scraper_2025-12-08_16-22-05-110-2.csv')
print(unfiltered_reviews_pd.head(3))
# Out:
#                                              address categories/0  \
# 0  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 1  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 2  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
#
#   categories/1 categories/2 categories/3 categories/4 categories/5  \
# 0  Bar & grill  Sports club          NaN          NaN          NaN
# 1  Bar & grill  Sports club          NaN          NaN          NaN
# 2  Bar & grill  Sports club          NaN          NaN          NaN
#
#   categories/6 categories/7 categories/8  ...     state  \
# 0          NaN          NaN          NaN  ...  Virginia
# 1          NaN          NaN          NaN  ...  Virginia
# 2          NaN          NaN          NaN  ...  Virginia
#
#                              street  temporarilyClosed  \
# 0  5070 Virginia Beach Blvd Suite B              False
# 1  5070 Virginia Beach Blvd Suite B              False
# ...

# %%
#Filter out unneeded columns
filtered_reviews_pd = unfiltered_reviews_pd[['address', 'categoryName', 'publishedAtDate', 'stars', 'text', 'totalScore']] #Filter out any unnecessary columns
print(filtered_reviews_pd.head(3))
# Out:
#                                              address categoryName  \
# 0  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 1  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 2  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
#
#             publishedAtDate  stars  \
# 0  2025-12-06T19:55:12.638Z    5.0
# 1  2025-11-23T19:47:57.892Z    5.0
# 2  2025-11-11T22:01:46.918Z    5.0
#
#                                                 text  totalScore
# 0  Had the best experience axe throwing for coupl...         4.8
# 1  Great Time doing something "different". Axe th...         4.8
# 2                        Grrat place amd great staff         4.8

# %%
#Check for Missing Data (Reviews, Stars, etc.)

# %%
#Handle the address replacement
def replace_address_with_name(text:str):
    """
    This takes the address column and replaces the address
    with the actual name of the restaurant
    Args:
        text (string): The address of the restaurant
    """
    if(text == " ")
        text = 
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    elif(text)
    
    return

# %%
#Exploratory Data Analysis
