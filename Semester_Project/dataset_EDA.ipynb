# %%
import pandas as pd
#Read in original dataset
unfiltered_reviews_pd = pd.read_csv('./dataset_Google-Maps-Reviews-Scraper_2025-12-08_16-22-05-110-2.csv')
print(unfiltered_reviews_pd)
# Out:
# /var/folders/rx/szmph7l52y799hrcx733zwh40000gn/T/ipykernel_8152/1574074487.py:3: DtypeWarning: Columns (15,16,20,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   unfiltered_reviews_pd = pd.read_csv('./dataset_Google-Maps-Reviews-Scraper_2025-12-08_16-22-05-110-2.csv')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 #Read in original dataset
#       3 unfiltered_reviews_pd = pd.read_csv('./dataset_Google-Maps-Reviews-Scraper_2025-12-08_16-22-05-110-2.csv')
# ----> 4 print(unfiltered_reviews_pd.sum())
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:11677, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668 @doc(make_doc("sum", ndim=2))
#   11669 def sum(
# ...

# %%
#Read in cleaned csv
# Out:
#                                              address categoryName  \
# 0  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 1  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
# 2  5070 Virginia Beach Blvd Suite B, Virginia Bea...  Event venue
#
#             publishedAtDate  stars  \
# 0  2025-12-06T19:55:12.638Z    5.0
# 1  2025-11-23T19:47:57.892Z    5.0
# 2  2025-11-11T22:01:46.918Z    5.0
#
#                                                 text  totalScore
# 0  Had the best experience axe throwing for coupl...         4.8
# 1  Great Time doing something "different". Axe th...         4.8
# 2                        Grrat place amd great staff         4.8

# %%
# Out:
# Number of missing items: address               0
# categoryName          0
# publishedAtDate       1
# stars                 1
# text               2634
# totalScore            1
# dtype: int64

# %%
# Out:
# address               0
# categoryName          0
# publishedAtDate       0
# stars                 0
# text               2633
# totalScore            0
# dtype: int64
